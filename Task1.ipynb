# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("1.csv")
df.head()
# Out:
#            Country Name Country Code     Indicator Name Indicator Code  \
# 0           Afghanistan          AFG  Population, total    SP.POP.TOTL
# 1               Albania          ALB  Population, total    SP.POP.TOTL
# 2               Andorra          AND  Population, total    SP.POP.TOTL
# 3  United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 4             Argentina          ARG  Population, total    SP.POP.TOTL
#
#          1960        1961        1962        1963        1964        1965  \
# 0   8622466.0   8790140.0   8969047.0   9157465.0   9355514.0   9565147.0
# 1   1608800.0   1659800.0   1711319.0   1762621.0   1814135.0   1864791.0
# 2      9443.0     10216.0     11014.0     11839.0     12690.0     13563.0
# 3    133426.0    140984.0    148877.0    157006.0    165305.0    173797.0
# 4  20349744.0  20680653.0  21020359.0  21364017.0  21708487.0  22053661.0
#
#    ...        2013        2014        2015        2016        2017  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
df.shape
# Out:
# (266, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 64 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  189 non-null    object
#  1   1960          189 non-null    float64
#  2   1961          189 non-null    float64
#  3   1962          189 non-null    float64
#  4   1963          189 non-null    float64
#  5   1964          189 non-null    float64
#  6   1965          189 non-null    float64
#  7   1966          189 non-null    float64
#  8   1967          189 non-null    float64
#  9   1968          189 non-null    float64
#  10  1969          189 non-null    float64
#  11  1970          189 non-null    float64
#  12  1971          189 non-null    float64
#  13  1972          189 non-null    float64
#  14  1973          189 non-null    float64
#  15  1974          189 non-null    float64
#  16  1975          189 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.890000e+02  1.890000e+02  1.890000e+02  1.890000e+02  1.890000e+02
# mean   1.584319e+07  1.605524e+07  1.633804e+07  1.668498e+07  1.703427e+07
# std    6.105038e+07  6.117100e+07  6.199352e+07  6.344752e+07  6.488081e+07
# min    4.582000e+03  4.753000e+03  4.950000e+03  5.198000e+03  5.484000e+03
# 25%    5.779330e+05  5.885970e+05  6.010950e+05  6.070720e+05  6.123380e+05
# 50%    3.028688e+06  3.087657e+06  3.148242e+06  3.210296e+06  3.273419e+06
# 75%    8.372311e+06  8.692048e+06  8.969047e+06  9.115091e+06  9.371333e+06
# max    6.670700e+08  6.603300e+08  6.657700e+08  6.823350e+08  6.983550e+08
#
#                1965          1966          1967          1968          1969  \
# count  1.890000e+02  1.890000e+02  1.890000e+02  1.890000e+02  1.890000e+02
# mean   1.738749e+07  1.775432e+07  1.812020e+07  1.849506e+07  1.888288e+07
# ...

# %%
df.isnull().sum()
# Out:
# Country Name    77
# 1960            77
# 1961            77
# 1962            77
# 1963            77
#                 ..
# 2018            77
# 2019            77
# 2020            77
# 2021            77
# 2022            77
# Length: 64, dtype: int64

# %%
country_population = df.groupby('Country Name').mean().reset_index()
country_population = country_population.sort_values(by='2022', ascending=False)
top_countries = country_population.head(10)
print(top_countries)
plt.xticks(rotation=90)
plt.bar(top_countries['Country Name'], top_countries['2022'], color="#f25ed0")
plt.title("Top 10 Countries with Highest Population in 2022")
plt.xlabel("Country Name")
plt.ylabel("Population")
plt.show()
# Out:
#            Country Name         1960         1961         1962         1963  \
# 75                India  445954579.0  456351876.0  467024193.0  477933619.0
# 33                China  667070000.0  660330000.0  665770000.0  682335000.0
# 180       United States  180671000.0  183691000.0  186538000.0  189242000.0
# 76            Indonesia   88382881.0   90816938.0   93345489.0   95962527.0
# 128            Pakistan   45954226.0   47060915.0   48161841.0   49325050.0
# 124             Nigeria   44928342.0   45855507.0   46821845.0   47822569.0
# 21               Brazil   73092515.0   75330008.0   77599218.0   79915555.0
# 11           Bangladesh   50396429.0   51882769.0   53461661.0   55094115.0
# 139  Russian Federation  119897000.0  121236000.0  122591000.0  123960000.0
# 109              Mexico   36268055.0   37439317.0   38683283.0   39982118.0
#
#             1964         1965         1966         1967         1968  ...  \
# ...

# %%
sns.distplot(df['2022'], bins=10, color='blue')
plt.title("Population Distribution in 2022")
plt.show()
